# %%
import matplotlib.pyplot as plt
from skimage.color import rgb2gray
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import matplotlib.image as maing
img = cv.imread('q1.jpeg', 0)
# cv.imshow('code',img)

# ret, th1 = cv.threshold(img, 0, 255, cv.THRESH_BINARY+cv.THRESH_OTSU)
adap = cv.adaptiveThreshold(img, 255, cv.ADAPTIVE_THRESH_GAUSSIAN_C,
                            cv.THRESH_BINARY, 31, 5)

cv.imshow("", adap)
cv.waitKey(0)
cv.destroyAllWindows()
plt.imshow(adap, "gray")

# %%
cv.imwrite()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\tejas\OneDrive\Desktop\KODIKON\31_ANTS\main.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/tejas/OneDrive/Desktop/KODIKON/31_ANTS/main.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> adap.save("q1.jpeg")
#
# AttributeError: 'numpy.ndarray' object has no attribute 'save'
